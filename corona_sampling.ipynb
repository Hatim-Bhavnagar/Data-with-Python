# %% [markdown]
# <a href="https://colab.research.google.com/github/Hatim-Bhavnagar/Data-with-Python/blob/main/corona_sampling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Step 1: Fetch the webpage
url = "https://www.worldometers.info/coronavirus/"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# Step 2: Find the main table
table = soup.find("table", id="main_table_countries_today")

# Step 3: Extract headers
headers = []
for th in table.thead.find_all("th"):
    headers.append(th.text.strip())

# Step 4: Extract rows
data = []
for row in table.tbody.find_all("tr"):
    cols = row.find_all("td")
    if cols:
        data.append([col.text.strip() for col in cols])

# Step 5: Build DataFrame
df = pd.DataFrame(data, columns=headers)

# Step 6: Save to CSV
df.to_csv("covid19_data.csv", index=False)
print("✅ Data saved to covid19_data.csv")
# Out:
# ✅ Data saved to covid19_data.csv
